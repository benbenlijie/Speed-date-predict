# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
df = pd.read_csv("Speed Dating Data.csv", encoding="cp1252")

# %%
pd.options.display.max_columns = 200

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
columns = list(df.columns.values)

# %%
import re

# %%
match_result = re.match(r"[^\d]+(\d_\d)", "attr1_2")
match_result.groups()
# Out:
# ('1_2',)

# %%
persondf = df.drop_duplicates("iid").set_index("iid")

# %%
len(persondf.index)
# Out:
# 551

# %%
persondf.head()
# Out:
#       id  gender  idg  condtn  wave  round  position  positin1  order  \
# iid
# 1    1.0       0    1       1     1     10         7       NaN      4
# 2    2.0       0    3       1     1     10         3       NaN     10
# 3    3.0       0    5       1     1     10         9       NaN      6
# 4    4.0       0    7       1     1     10         6       NaN      3
# 5    5.0       0    9       1     1     10         4       NaN      1
#
#      partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# iid
# 1          1  11.0      0      0.14         0   27.0     2.0      35.0
# 2          1  11.0      0      0.29         1   27.0     2.0      35.0
# 3          1  11.0      0     -0.24         1   27.0     2.0      35.0
# 4          1  11.0      0     -0.18         1   27.0     2.0      35.0
# 5          1  11.0      0     -0.43         1   27.0     2.0      35.0
#
#      pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# iid
# ...

# %%
matchdf = df[["iid", "pid", "match"]]

# %%
matchdf.head()
# Out:
#    iid   pid  match
# 0    1  11.0      0
# 1    1  12.0      0
# 2    1  13.0      1
# 3    1  14.0      1
# 4    1  15.0      1

# %%
match_amount = len(matchdf.index)

train_size = int(match_amount * 0.8)
test_size = match_amount - train_size
batch_count = 10
batch_size = int(train_size / batch_count)

print(train_size, test_size, batch_size)
# Out:
# 6702 1676 670

# %%
train_data = matchdf.iloc[:train_size, :]
test_data = matchdf.iloc[train_size:, :]

# %%
from sklearn.decomposition import PCA

# %%
feature_columns = ['age', 'race', 'imprace', 'imprelig', 'income',
                   'goal', 'date', 'go_out', 'career_c',
                   'sports', 'tvsports', 'exercise', 'dining', 'museums',
                   'art', 'hiking', 'gaming', 'clubbing', 'reading',
                   'tv', 'theater', 'movies', 'concerts', 'music',
                   'shopping', 'yoga', 'exphappy', 'expnum', 
                   'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',
                   'attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1',
                   'attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1',]

# %%
def check_columns(columns, newColumn):
    persondf[newColumn] = 0
    for column in columns:
        persondf[newColumn] += persondf[column]
    print(persondf[newColumn].value_counts())
    print(persondf[newColumn].describe())

# %%
wave1_1_columns = ['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',]
check_columns(wave1_1_columns, "1_1_values")
# Out:
# 100.00    466
# 100.01     15
# 99.99      14
# 100.01     10
# 100.02      6
# 100.00      6
# 99.99       5
# 90.00       4
# 100.02      3
# 100.00      3
# 99.98       2
# 120.00      2
# 110.00      1
# 101.00      1
# 99.99       1
# 95.00       1
# 148.00      1
# Name: 1_1_values, dtype: int64
# count    541.000000
# mean     100.100166
# std        2.590789
# min       90.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max      148.000000
# Name: 1_1_values, dtype: float64
# C:\Users\Administrator\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)

# %%
persondf[["wave", "1_1_values"] + wave1_1_columns][persondf["1_1_values"] > 120]
# Out:
#      wave  1_1_values  attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# iid
# 66      3       148.0     20.0     25.0      15.0    15.0    53.0     20.0

# %%
wave2_1_columns = ['attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1',]
check_columns(wave2_1_columns, "2_1_values")
# Out:
# 100.00    458
# 100.02     13
# 100.01     11
# 99.99      10
# 100.01      9
# 100.00      7
# 110.00      6
# 99.99       6
# 90.00       4
# 105.00      4
# 95.00       3
# 100.02      3
# 99.99       2
# 99.98       1
# 101.00      1
# 100.00      1
# 100.02      1
# 100.03      1
# 80.00       1
# 112.00      1
# Name: 2_1_values, dtype: int64
# count    543.000000
# mean     100.033831
# std        1.781097
# min       80.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max      112.000000
# Name: 2_1_values, dtype: float64
# C:\Users\Administrator\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)

# %%
wave3_1_columns = ['attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1',]
check_columns(wave3_1_columns, "3_1_values")
# Out:
# 40.0    59
# 42.0    53
# 41.0    45
# 39.0    44
# 37.0    41
# 38.0    41
# 35.0    31
# 36.0    30
# 43.0    29
# 45.0    25
# 33.0    20
# 44.0    20
# 46.0    19
# 34.0    16
# 32.0    14
# 31.0    10
# 30.0    10
# 50.0     7
# 48.0     7
# 47.0     5
# 29.0     5
# 25.0     3
# 49.0     2
# 28.0     2
# 26.0     1
# 24.0     1
# 23.0     1
# 18.0     1
# Name: 3_1_values, dtype: int64
# count    542.000000
# mean      39.042435
# std        4.727710
# min       18.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max       50.000000
# Name: 3_1_values, dtype: float64
# C:\Users\Administrator\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)

# %%
wave5_1_columns = ['attr5_1', 'sinc5_1', 'intel5_1', 'fun5_1', 'amb5_1',]
check_columns(wave5_1_columns, "5_1_values")
# Out:
# 42.0    35
# 36.0    25
# 41.0    25
# 40.0    23
# 39.0    21
# 37.0    19
# 38.0    18
# 35.0    17
# 34.0    16
# 32.0    14
# 45.0    12
# 44.0    12
# 43.0    10
# 30.0    10
# 31.0     9
# 33.0     9
# 46.0     6
# 48.0     6
# 50.0     5
# 47.0     5
# 29.0     3
# 27.0     3
# 26.0     3
# 25.0     3
# 28.0     2
# 18.0     2
# 22.0     1
# Name: 5_1_values, dtype: int64
# count    314.000000
# mean      38.108280
# std        5.483731
# min       18.000000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max       50.000000
# Name: 5_1_values, dtype: float64
# C:\Users\Administrator\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)

# %%
feature_df = persondf[feature_columns].copy()

# %%
feature_df.head()
# Out:
#       age  race  imprace  imprelig     income  goal  date  go_out  career_c  \
# iid
# 1    21.0   4.0      2.0       4.0  69,487.00   2.0   7.0     1.0       NaN
# 2    24.0   2.0      2.0       5.0  65,929.00   1.0   5.0     1.0       NaN
# 3    25.0   2.0      8.0       4.0        NaN   6.0   3.0     1.0       NaN
# 4    23.0   2.0      1.0       1.0  37,754.00   1.0   5.0     1.0       1.0
# 5    21.0   2.0      8.0       1.0  86,340.00   2.0   4.0     1.0       1.0
#
#      sports  tvsports  exercise  dining  museums  art  hiking  gaming  \
# iid
# 1       9.0       2.0       8.0     9.0      1.0  1.0     5.0     1.0
# 2       3.0       2.0       7.0    10.0      8.0  6.0     3.0     5.0
# 3       3.0       8.0       7.0     8.0      5.0  5.0     8.0     4.0
# 4       1.0       1.0       6.0     7.0      6.0  7.0     7.0     5.0
# 5       7.0       4.0       7.0     7.0      6.0  8.0     6.0     6.0
#
# ...

# %%
pca = PCA(n_components="mle")

# %%
feature_df.dtypes
# Out:
# age         float64
# race        float64
# imprace     float64
# imprelig    float64
# income       object
# goal        float64
# date        float64
# go_out      float64
# career_c    float64
# sports      float64
# tvsports    float64
# exercise    float64
# dining      float64
# museums     float64
# art         float64
# hiking      float64
# gaming      float64
# clubbing    float64
# reading     float64
# tv          float64
# theater     float64
# movies      float64
# concerts    float64
# music       float64
# shopping    float64
# yoga        float64
# exphappy    float64
# expnum      float64
# attr1_1     float64
# sinc1_1     float64
# intel1_1    float64
# fun1_1      float64
# amb1_1      float64
# shar1_1     float64
# attr2_1     float64
# sinc2_1     float64
# intel2_1    float64
# fun2_1      float64
# amb2_1      float64
# shar2_1     float64
# attr3_1     float64
# sinc3_1     float64
# fun3_1      float64
# intel3_1    float64
# amb3_1      float64
# ...

# %%
feature_df["age"].median()
# Out:
# 26.0

# %%
feature_df["income"] = feature_df["income"].apply(lambda x: x.replace(',', '') if type(x) is str else x)

feature_df["income"] = feature_df["income"].fillna(feature_df["income"].median()).astype("float64")

# %%
feature_df.describe()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4116: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#               age        race     imprace    imprelig         income  \
# count  543.000000  545.000000  544.000000  544.000000     551.000000
# mean    26.359116    2.800000    3.733456    3.582721   44256.286751
# std      3.766960    1.253818    2.842181    2.784553   12702.384591
# min     18.000000    1.000000    0.000000    1.000000    8607.000000
# 25%           NaN         NaN         NaN         NaN   42774.000000
# 50%           NaN         NaN         NaN         NaN   43185.000000
# 75%           NaN         NaN         NaN         NaN   43650.000000
# max     55.000000    6.000000   10.000000   10.000000  109031.000000
#
#              goal        date      go_out    career_c      sports    tvsports  \
# count  544.000000  543.000000  544.000000  539.000000  544.000000  544.000000
# ...

# %%
pd.isnull(feature_df.iloc[:, 0:2]).any(1).nonzero()[0]
# Out:
# array([ 57,  58, 127, 134, 337, 338, 344, 510], dtype=int64)

# %%
feature_df = feature_df.fillna(feature_df.mean())

# %%
def check_null():
    (index, col) = np.where(feature_df.isnull())
    for pos in zip(index, col):
        print(pos)
check_null()
# Out:
# (2, 45)
# (7, 45)
# (8, 45)
# (10, 45)
# (12, 45)
# (15, 45)
# (18, 45)
# (19, 45)
# (20, 45)
# (22, 45)
# (27, 45)
# (29, 45)
# (31, 45)
# (33, 45)
# (35, 45)
# (40, 45)
# (42, 45)
# (43, 45)
# (44, 45)
# (45, 45)
# (46, 45)
# (47, 45)
# (52, 45)
# (56, 45)
# (57, 45)
# (58, 45)
# (59, 45)
# (64, 45)
# (65, 45)
# (68, 45)
# (71, 45)
# (72, 45)
# (73, 45)
# (78, 45)
# (79, 45)
# (82, 45)
# (83, 45)
# (86, 45)
# (88, 45)
# (89, 45)
# (92, 45)
# (93, 45)
# (95, 45)
# (99, 45)
# (100, 45)
# (101, 45)
# (107, 45)
# (108, 45)
# (110, 45)
# (111, 45)
# (113, 45)
# (115, 45)
# (117, 45)
# (125, 45)
# (126, 45)
# (127, 45)
# (128, 45)
# (131, 45)
# (133, 45)
# (134, 45)
# (137, 45)
# (138, 45)
# (139, 45)
# (141, 45)
# (146, 45)
# (149, 45)
# (150, 45)
# (151, 45)
# (157, 45)
# (160, 45)
# (168, 45)
# (169, 45)
# (170, 45)
# (171, 45)
# (174, 45)
# (176, 45)
# (178, 45)
# (180, 45)
# (181, 45)
# (183, 45)
# (185, 45)
# (187, 45)
# (188, 45)
# (189, 45)
# (194, 45)
# (196, 45)
# (199, 45)
# ...

# %%
feature_df = feature_df.drop("income_num", axis=1)

# %%
pca.fit(feature_df)
# Out:
# PCA(copy=True, n_components='mle', whiten=False)

# %%
newData = pca.fit_transform(feature_df)

# %%
type(newData)
# Out:
# numpy.ndarray

# %%
newData.shape
# Out:
# (551, 42)

# %%
feature_df.shape
# Out:
# (551, 45)

# %%
inverse_data = pd.DataFrame(pca.inverse_transform(newData))

# %%
inverse_data.head()
# Out:
#           0         1         2         3             4         5         6   \
# 0  20.992003  3.994786  1.991328  4.003093  69486.999999  2.025499  6.989515
# 1  23.992718  2.111834  2.029426  5.029266  65928.999993  1.059640  4.986681
# 2  24.995577  1.991683  7.990066  3.998187  43185.000000  5.998006  3.003237
# 3  23.011126  1.974933  0.991166  0.981249  37754.000002  0.909717  5.043145
# 4  20.970278  1.971407  7.995469  1.030071  86340.000000  2.221752  3.881419
#
#          7         8         9         10        11         12        13  \
# 0  0.979871  5.233854  8.988256  1.998933  7.998366   8.993245  1.255589
# 1  1.014178  5.233381  3.036927  2.037081  6.975110  10.133295  7.172067
# 2  0.959745  5.244912  2.983353  8.001424  7.007852   7.976692  5.203512
# 3  0.933274  1.034654  0.978507  1.002696  6.032560   6.930145  5.977948
# 4  1.171605  0.906467  7.024130  3.958865  6.926649   7.081780  6.919044
#
# ...

# %%
feature_df.head()
# Out:
#       age  race  imprace  imprelig   income  goal  date  go_out  career_c  \
# iid
# 1    21.0   4.0      2.0       4.0  69487.0   2.0   7.0     1.0  5.250464
# 2    24.0   2.0      2.0       5.0  65929.0   1.0   5.0     1.0  5.250464
# 3    25.0   2.0      8.0       4.0  43185.0   6.0   3.0     1.0  5.250464
# 4    23.0   2.0      1.0       1.0  37754.0   1.0   5.0     1.0  1.000000
# 5    21.0   2.0      8.0       1.0  86340.0   2.0   4.0     1.0  1.000000
#
#      sports  tvsports  exercise  dining  museums  art  hiking  gaming  \
# iid
# 1       9.0       2.0       8.0     9.0      1.0  1.0     5.0     1.0
# 2       3.0       2.0       7.0    10.0      8.0  6.0     3.0     5.0
# 3       3.0       8.0       7.0     8.0      5.0  5.0     8.0     4.0
# 4       1.0       1.0       6.0     7.0      6.0  7.0     7.0     5.0
# 5       7.0       4.0       7.0     7.0      6.0  8.0     6.0     6.0
#
#      clubbing  reading   tv  theater  movies  concerts  music  shopping  yoga  \
# iid
# ...

# %%
feature_df.iloc[0, :].values
# Out:
# array([  2.10000000e+01,   4.00000000e+00,   2.00000000e+00,
#          4.00000000e+00,   6.94870000e+04,   2.00000000e+00,
#          7.00000000e+00,   1.00000000e+00,   5.25046382e+00,
#          9.00000000e+00,   2.00000000e+00,   8.00000000e+00,
#          9.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          5.00000000e+00,   1.00000000e+00,   5.00000000e+00,
#          6.00000000e+00,   9.00000000e+00,   1.00000000e+00,
#          1.00000000e+01,   1.00000000e+01,   9.00000000e+00,
#          8.00000000e+00,   1.00000000e+00,   3.00000000e+00,
#          2.00000000e+00,   1.50000000e+01,   2.00000000e+01,
#          2.00000000e+01,   1.50000000e+01,   1.50000000e+01,
#          1.50000000e+01,   3.50000000e+01,   2.00000000e+01,
#          1.50000000e+01,   2.00000000e+01,   5.00000000e+00,
#          5.00000000e+00,   6.00000000e+00,   8.00000000e+00,
#          8.00000000e+00,   8.00000000e+00,   7.00000000e+00])

# %%
### build network

pe_a = tf.placeholder(tf.float32, shape=[None, len(feature_df.columns)])
pe_b = tf.placeholder(tf.float32, shape=[None, len(feature_df.columns)])
dropout = tf.placeholder(tf.float32)

inputs_ab = tf.concat([pe_a, pe_b], 1)
inputs_ba = tf.concat([pe_b, pe_a], 1)
labels = tf.placeholder(tf.float32, shape=[None, 1])

# %%
input_len = inputs.get_shape()[1].value
hidden_1_len = 60
hidden_2_len = 10
output_count = 1

# %%
def add_layer(x_tensor, weights, biases):
    output = tf.matmul(x_tensor, weights) + biases
    output = tf.nn.relu(output)
    return output

# %%
weights = {
    "fc1": tf.Variable(tf.truncated_normal([input_len, hidden_1_len])),
    "fc2": tf.Variable(tf.truncated_normal([hidden_1_len, hidden_2_len])),
    "fc3": tf.Variable(tf.truncated_normal([hidden_2_len, output_count])),
}
biases = {
    "b1": tf.Variable(tf.zeros(hidden_1_len)),
    "b2": tf.Variable(tf.zeros(hidden_2_len)),
    "b3": tf.Variable(tf.zeros(output_count)),
}

# %%
hidden_1_layer_ab = add_layer(inputs_ab, weights["fc1"], biases["b1"])
hidden_2_layer_ab = add_layer(hidden_1_layer_ab, weights["fc2"], biases["b2"])
hidden_2_layer_ab = tf.nn.dropout(hidden_2_layer_ab, keep_prob=dropout)

hidden_1_layer_ba = add_layer(inputs_ba, weights["fc1"], biases["b1"])
hidden_2_layer_ba = add_layer(hidden_1_layer_ba, weights["fc2"], biases["b2"])
hidden_2_layer_ba = tf.nn.dropout(hidden_2_layer_ba, keep_prob=dropout)


digits = tf.matmul(hidden_2_layer_ab, weights["fc3"]) + tf.matmul(hidden_2_layer_ba, weights["fc3"]) + biases["b3"]

# %%
n_epochs = 10
learning_rate = 1
cost = tf.nn.sigmoid_cross_entropy_with_logits(labels=labels, logits=digits)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
train_pair = train_data.loc[0:10, ['iid', 'pid']].values

for [iid, pid] in train_pair:
    print(iid, pid)
# Out:
# 1.0 11.0
# 1.0 12.0
# 1.0 13.0
# 1.0 14.0
# 1.0 15.0
# 1.0 16.0
# 1.0 17.0
# 1.0 18.0
# 1.0 19.0
# 1.0 20.0
# 2.0 11.0

# %%
def get_profile(iid):
    return feature_df.loc[iid, :].values

def gen_profile(match_pair):
    iids, pids = [], []
    for [iid, pid] in match_pair:
        iids.append(get_profile(iid))
        pids.append(get_profile(pid))
    return np.array(iids), np.array(pids)


iids, pids = gen_profile(train_data.loc[0:10, ['iid', 'pid']].values)
print(iids.shape)
print(pids.shape)
# Out:
# (11, 45)
# (11, 45)

# %%
cost_record = []
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(n_epochs):
        cv_index = random.randint(0, batch_count)
        for j in range(batch_count):
            if j == cv_index:
                continue;
            iids, pids = gen_profile(train_data.iloc[j:j+batch_size, ['iid', 'pid']].values)
            sess.run(optimizer, feed_dict={
                    pe_a:iids,
                    pe_b:pids,
                    dropout:0.5
                })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-262-2c727d77ce96> in <module>()
#       7             if j == cv_index:
#       8                 continue;
# ----> 9             iids, pids = gen_profile(train_data.iloc[j:j+batch_size, :].values)
#      10             sess.run(optimizer, feed_dict={})
#
# <ipython-input-261-8280a3122ad4> in gen_profile(match_pair)
#       4 def gen_profile(match_pair):
#       5     iids, pids = [], []
# ----> 6     for [iid, pid] in match_pair:
#       7         iids.append(get_profile(iid))
#       8         pids.append(get_profile(pid))
#
# ValueError: too many values to unpack (expected 2)
